# %%
import numpy as np
import math

# %%
np.random.seed(37)
n = 78
data = np.random.randn(n) + np.random.random(n) * np.e
x_grid = np.linspace(np.min(data), np.max(data))
h = 0.7

# %%
# (1, 50,) x_grid
# (10, 1) X

# %%
import matplotlib.pyplot as plt
def K(x):
    return np.exp(-np.power(x, 2)/2)/math.sqrt(2*math.pi)

def f(X, h):
    x_grid = np.linspace(np.min(X), np.max(X), )
    n = X.size
    total_sum = np.sum(K((x_grid - X[:, np.newaxis])/h), axis=0)
    """total_sum = 0
    for xi in X:
        total_sum += K((x_grid - xi)/h)"""
    y_range = total_sum/(h*n)
    plt.plot(x_grid, y_range,  
            label=f'{h}')

    plt.plot(data, np.zeros_like(data) , 's', 
            markersize=8, color='black')
        
    return total_sum
f(data, h)
# Out:
# array([ 2.31405445,  2.72186289,  3.16807275,  3.65053607,  4.16548222,
#         4.70712603,  5.26735582,  5.83561668,  6.39911282,  6.94343343,
#         7.45365422,  7.9158815 ,  8.31909937,  8.65707386,  8.92998823,
#         9.14545851,  9.31862496,  9.47113658,  9.62902449,  9.81966244,
#        10.06819603, 10.39394579, 10.80732354, 11.30773879, 11.88282325,
#        12.50909825, 13.15399062, 13.778909  , 14.34295513, 14.80678346,
#        15.13613832, 15.30468174, 15.29585332, 15.10365318, 14.73238271,
#        14.19549738, 13.51380679, 12.71329635, 11.82284213, 10.8720563 ,
#         9.88944234,  8.9009715 ,  7.92912354,  6.99237573,  6.10507982,
#         5.27763983,  4.51689439,  3.82661216,  3.20802425,  2.66033785])
